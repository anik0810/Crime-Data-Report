# %%
import pandas as pd
df=pd.read_csv('crime.csv')

# %%
df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
data_andhra=df.loc[df['STATE/UT']=='ANDHRA PRADESH']
data_andhra=data_andhra.loc[df['YEAR']==2001]

# %%
data_andhra
# Out:
#           STATE/UT           DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0   ANDHRA PRADESH           ADILABAD  2001     101                 60
# 1   ANDHRA PRADESH          ANANTAPUR  2001     151                125
# 2   ANDHRA PRADESH           CHITTOOR  2001     101                 57
# 3   ANDHRA PRADESH           CUDDAPAH  2001      80                 53
# 4   ANDHRA PRADESH      EAST GODAVARI  2001      82                 67
# 5   ANDHRA PRADESH      GUNTAKAL RLY.  2001       3                  1
# 6   ANDHRA PRADESH             GUNTUR  2001     182                 88
# 7   ANDHRA PRADESH     HYDERABAD CITY  2001     111                113
# 8   ANDHRA PRADESH         KARIMNAGAR  2001     162                 85
# 9   ANDHRA PRADESH            KHAMMAM  2001      93                 60
# 10  ANDHRA PRADESH            KRISHNA  2001      65                 51
# 11  ANDHRA PRADESH            KURNOOL  2001     133                 72
# ...

# %%
data_andhra_2001=data_andhra.drop(['STATE/UT','DISTRICT','YEAR','TOTAL IPC CRIMES'],1)
# data_andhra.drop(['YEAR'],1)
# Out:
# C:\Users\Anikd\AppData\Local\Temp\ipykernel_1644\2682695550.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data_andhra_2001=data_andhra.drop(['STATE/UT','DISTRICT','YEAR','TOTAL IPC CRIMES'],1)

# %%
data_sum=data_andhra_2001.sum()
data_sum
# Out:
# MURDER                                                  5204
# ATTEMPT TO MURDER                                       3110
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                272
# RAPE                                                    1742
# CUSTODIAL RAPE                                             0
# OTHER RAPE                                              1742
# KIDNAPPING & ABDUCTION                                  2364
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             1530
# KIDNAPPING AND ABDUCTION OF OTHERS                       834
# DACOITY                                                  428
# PREPARATION AND ASSEMBLY FOR DACOITY                      18
# ROBBERY                                                 1258
# BURGLARY                                               14440
# THEFT                                                  33502
# AUTO THEFT                                              6102
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (15, 5))
data_sum.plot(kind='bar',width=0.6,color='maroon')
# Out:
# <AxesSubplot:>

# %%
print(f"The most occured crime is HURT/GREVIOUS HURT and the number is {data_sum.max()} in 2001")
# Out:
# The most occured crime is HURT/GREVIOUS HURT and the number is 34947 in 2001

# %%
data_andhra=df.loc[df['STATE/UT']=='ANDHRA PRADESH']
data_andhra_2001=data_andhra.loc[df['YEAR']==2001]
data_andhra_2001=data_andhra_2001.drop(28)

# %%
# data_andhra_2001
fig = plt.figure(figsize = (15, 5))
y=data_andhra_2001['TOTAL IPC CRIMES']
x=data_andhra_2001['DISTRICT']
plt.bar(x,y,color='maroon')
plt.xticks(rotation='vertical')
plt.show()

# %%
data_andhra_2002=df.loc[df['STATE/UT']=='ANDHRA PRADESH']
data_andhra_2002=data_andhra_2002.loc[df['YEAR']==2002]

# %%
data_andhra_2002
# Out:
#            STATE/UT           DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 716  ANDHRA PRADESH           ADILABAD  2002     100                 79
# 717  ANDHRA PRADESH          ANANTAPUR  2002     166                113
# 718  ANDHRA PRADESH           CHITTOOR  2002     105                 66
# 719  ANDHRA PRADESH           CUDDAPAH  2002      91                  0
# 720  ANDHRA PRADESH      EAST GODAVARI  2002      97                102
# 721  ANDHRA PRADESH      GUNTAKAL RLY.  2002       0                  0
# 722  ANDHRA PRADESH             GUNTUR  2002     143                 77
# 723  ANDHRA PRADESH     HYDERABAD CITY  2002     117                109
# 724  ANDHRA PRADESH         KARIMNAGAR  2002     160                 88
# 725  ANDHRA PRADESH            KHAMMAM  2002     106                 55
# 726  ANDHRA PRADESH            KRISHNA  2002      92                 66
# 727  ANDHRA PRADESH            KURNOOL  2002     124                 98
# ...

# %%
data_andhra_2002=data_andhra_2002.drop(['STATE/UT','DISTRICT','YEAR'],1)
data_andhra_2002=data_andhra_2002.drop(['TOTAL IPC CRIMES'],1)
# data_andhra.drop(['YEAR'],1)
# Out:
# C:\Users\Anikd\AppData\Local\Temp\ipykernel_1644\197949504.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data_andhra_2002=data_andhra_2002.drop(['TOTAL IPC CRIMES'],1)

# %%
data_sum2=data_andhra_2001.sum()
data_sum2
# Out:
# MURDER                                                  5204
# ATTEMPT TO MURDER                                       3110
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                272
# RAPE                                                    1742
# CUSTODIAL RAPE                                             0
# OTHER RAPE                                              1742
# KIDNAPPING & ABDUCTION                                  2364
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             1530
# KIDNAPPING AND ABDUCTION OF OTHERS                       834
# DACOITY                                                  428
# PREPARATION AND ASSEMBLY FOR DACOITY                      18
# ROBBERY                                                 1258
# BURGLARY                                               14440
# THEFT                                                  33502
# AUTO THEFT                                              6102
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (15, 5))
data_sum2.plot(kind='bar',width=0.6,color='green')
# Out:
# <AxesSubplot:>

# %%
data_andhra=df.loc[df['STATE/UT']=='ANDHRA PRADESH']
data_andhra_2002=data_andhra.loc[df['YEAR']==2002]
data_andhra_2002=data_andhra_2002.drop(744)

# %%
# data_andhra_2002
fig = plt.figure(figsize = (15, 5))
y=data_andhra_2002['TOTAL IPC CRIMES']
x=data_andhra_2002['DISTRICT']
plt.bar(x,y,color='green')
plt.xticks(rotation='vertical')
plt.show()
